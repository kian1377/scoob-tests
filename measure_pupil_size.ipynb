# %%
import numpy as np
from astropy.io import fits
from lina.imshows import *
from matplotlib.patches import Circle

# %%
pup_ims = fits.getdata('basler_pupil_image_cube_without_vvc_1.fits')
vvc_pup_ims = fits.getdata('basler_pupil_image_cube_with_vvc_3.fits')

# %%
patches1 = [Circle((1270, 1400), 420, color='c', fill=False)]
patches2 = [Circle((1260, 1360), 425, color='c', fill=False)]
imshow2(pup_ims, vvc_pup_ims, patches1=patches1, patches2=patches2, wspace=0.3)

vvc_pup_ims.shape
# Out:
# (2048, 2592)
