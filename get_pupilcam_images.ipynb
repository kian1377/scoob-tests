# %%
import scoobpy
from scoobpsf.imshows import *

cam = scoobpy.utils.connect_to_camshmim()

imshow1(cam.grab_latest())

# %%
from scoobpsf import scoobi
scoobi.move_psf(-1,0)

# %%
scoobi.move_psf(-2,0)

# %%
scoobpy.camctrl
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 scoobpy.camctrl
#
# AttributeError: module 'scoobpy' has no attribute 'camctrl'

# %%
pixelscale

# %%
from magpyx.utils import ImageStream

def snap():
    return ImageStream('pupilcam').grab_latest()

# %%
pupim = snap()
imshow1(pupim)

# %%
import numpy as np

# %%
pupims = []
for i in range(10):
    pupims.append(snap())

# %%
import lina

# %%
lina.utils.save_fits('basler_pupil_image_cube_without_vvc_1.fits', np.array(pupim))
# Out:
# Saved data to:  basler_pupil_image_cube_without_vvc_1.fits

# %%
imshow1(pupims[4])
